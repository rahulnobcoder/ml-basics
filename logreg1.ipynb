# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mpl
import math
from sklearn.metrics import accuracy_score

# %%
data=pd.read_csv("Social_Network_Ads.csv")
data
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
data=data.drop(columns="User ID")

# %%
data.insert(0,"trash",1)

# %%
X=data.drop(columns="Purchased")
Y=data["Purchased"]
X["Gender"]=X["Gender"].replace(["Male","Female"],[1,0])
Xt=X.transpose()
a=np.linalg.inv(np.matmul(Xt,X))
a=np.matmul(a,Xt)
mat=np.matmul(a,Y)
mat
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_1680\2153460342.py:5: FutureWarning: Calling a ufunc on non-aligned DataFrames (or DataFrame/Series combination). Currently, the indices are ignored and the result takes the index/columns of the first DataFrame. In the future , the DataFrames/Series will be aligned before applying the ufunc.
# Convert one of the arguments to a NumPy array (eg 'ufunc(df1, np.asarray(df2)') to keep the current behaviour, or align manually (eg 'df1, df2 = df1.align(df2)') before passing to the ufunc to obtain the future behaviour and silence this warning.
#   a=np.linalg.inv(np.matmul(Xt,X))
# 0   -0.920305
# 1    0.016192
# 2    0.026611
# 3    0.000004
# dtype: float64

# %%
def predict(a,b,c,d):
    y=d[0]+a*d[1]+b*d[2]+c*d[3]
    return y
pred=[]
for i in range(400):
    pred.append(predict(X.iloc[i,1],X.iloc[i,2],X.iloc[i,3],mat))
pred
# Out:
# [-0.3255336342321305,
#  0.1040903001072541,
#  -0.06328401562787722,
#  0.017088338622725185,
#  -0.10665012383211087,
#  0.0371207039972242,
#  0.12077000144378708,
#  0.5072715263529375,
#  -0.11210381974608469,
#  0.2607007676871569,
#  0.07879826305283727,
#  -0.028723461354189905,
#  -0.04163801592536964,
#  0.016575700794057444,
#  -0.11022124636340808,
#  0.17482504298263718,
#  0.44262851260214475,
#  0.3932455900939327,
#  0.427537205312952,
#  0.46840794720456086,
#  0.37788534375007166,
#  0.5185976868767772,
#  0.5306809900246776,
#  0.3616930399615379,
#  0.40833689738312573,
#  0.4234282046723185,
#  0.5073716814542182,
#  0.4456365167434373,
#  0.03274276430192269,
#  -0.010035791253031237,
#  0.20500765756102313,
#  0.32429326549994564,
#  -0.30002313868438263,
#  -0.006220969947734467,
#  0.16000267474811242,
#  0.1309707312090109,
#  0.06539550491226492,
#  0.08239462586480303,
#  0.048077770365115235,
#  -0.0827532626123715,
#  -0.1365141248158851,
# ...

# %%
for i in range(400):
    pred[i]=1/(1+math.exp(-pred[i]))

# %%
pred
# Out:
# [0.4193277539280945,
#  0.5259991046935439,
#  0.48418427406350595,
#  0.5042719807006281,
#  0.4733627125184507,
#  0.5092791105138265,
#  0.5301558563491738,
#  0.6241666390652968,
#  0.4720033590278773,
#  0.5648085482129762,
#  0.5196893789317458,
#  0.49281962832749526,
#  0.4895919996921904,
#  0.5041438303211686,
#  0.47247255138067035,
#  0.5435952808282214,
#  0.6088851741467145,
#  0.5970637642736912,
#  0.605285422716254,
#  0.61500686969254,
#  0.5933629724841644,
#  0.626819800180954,
#  0.6296419280690408,
#  0.5894502094203808,
#  0.6006890310772385,
#  0.6043032974082315,
#  0.6241901334217462,
#  0.6096012772585524,
#  0.508184959838359,
#  0.4974910732443604,
#  0.5510731637238353,
#  0.5803701960371604,
#  0.42555182675436554,
#  0.4984447625287645,
#  0.5399155489811195,
#  0.5326959591037572,
#  0.5163430522897583,
#  0.5205870108979195,
#  0.5120171279092226,
#  0.47932348257622354,
#  0.4659243721182305,
#  0.5383537387098493,
#  0.6087392314423297,
# ...

# %%
for i in range(400):
    if pred[i]<0.5:
        pred[i]=0
    else:
        pred[i]=1
a=0
for i in range(400):
    if pred[i]==Y[i]:
        a+=1
a/400
# Out:
# 0.5125

# %%
b=int(input("whats your gender/0-male,1-female"))
c=int(input("whats your age"))
d=int(input("your salary"))
k=1/(1+math.exp(-predict(b,c,d,mat)))
if k<0.5:
    print(0)
else:
    print(1)
# Out:
# whats your gender0
# whats your age19
# your salary15000
# 0
